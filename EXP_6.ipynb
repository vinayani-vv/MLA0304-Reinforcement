# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayani-vv/MLA0304-Reinforcement/blob/main/EXP_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

env = gym.make("FrozenLake-v1", is_slippery=False)

state, info = env.reset()

for _ in range(5):
    action = env.action_space.sample()
    state, reward, terminated, truncated, info = env.step(action)
    print("State:", state, "Reward:", reward)
    if terminated or truncated:
        break

env.close()
# Out:
# State: 4 Reward: 0
# State: 4 Reward: 0
# State: 4 Reward: 0
# State: 4 Reward: 0
# State: 0 Reward: 0
