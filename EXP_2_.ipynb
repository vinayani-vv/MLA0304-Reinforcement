# %% [markdown]
# <a href="https://colab.research.google.com/github/vinayani-vv/MLA0304-Reinforcement/blob/main/EXP_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

rooms = ["Kitchen", "Hall", "Bedroom", "Charging"]

state = random.choice(rooms)

for i in range(5):
    action = random.choice(["Move", "Charge"])
    if action == "Move":
        state = random.choice(rooms)
    reward = 10 if state == "Charging" else -1
    print(f"Action: {action}, Room: {state}, Reward: {reward}")
# Out:
# Action: Move, Room: Bedroom, Reward: -1
# Action: Charge, Room: Bedroom, Reward: -1
# Action: Charge, Room: Bedroom, Reward: -1
# Action: Move, Room: Bedroom, Reward: -1
# Action: Move, Room: Kitchen, Reward: -1
